# %% [markdown]
# # F1 ERS Deployment Analytics — Demo Notebook
# This notebook walks through generating synthetic telemetry, creating features, training a short PPO agent, building a RAG index, and launching a Gradio app.

# %%
import sys
print('Python', sys.version)
from pathlib import Path
Path().resolve()

# %%
# Generate synthetic telemetry (short run)
# !python -m src.data_gen
print('Generated data saved to outputs/')

# %%
# Create features (segments + lap summary)
# !python -m src.features
print('Features saved to outputs/')

# %%
# Train PPO for a short demo (lower timesteps for notebook runtime)
# !python -m src.train
print('Training (demo) complete — check outputs/ for ppo_real_rewards.png')

# %%
# Build RAG index
# !python -m src.rag
print('RAG index built (rag_index/)')

# %%
# Launch the Gradio app (run in a terminal, not recommended inside notebook for long-running)
print('To launch: python app.py')
